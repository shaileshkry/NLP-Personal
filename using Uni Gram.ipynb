# %%
import spacy
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
nlp=spacy.load('en_core_web_lg')

# %%
txt="""A hint of controversy as we wrap up the coverage of the 3rd T20I. Was Rohit declared retired out / retired hurt. If it was the former, he couldn't have come out to bat for the second time, but is there any ambiguity in the game that he could have walked away retired hurt in the first super-over? If so, Rohit has played the rules perfectly. A 212 play 212 in the regular passage of play. A sublime hundred from Rohit after his 2 ducks in the first two games. A record 5th wicket partnership to haul India out of choppy waters at 22 for 4. It was followed by a team batting display as Afghanistan fought hard to drag the match into a super over. Another bit of controversy happened there with Nabi happy to take runs after a deflection off his body, 16 played 16 and we didn't have a winner. A second super over was played and we finally had a winner for the night. Lots of fours, sixes , wickets and an Indian win to savour for the crowd at the Chinnaswamy and we'll leave with only good memories. India now turn their attention towards red-ball cricket and the 5-match Test series against England starts shortly in Hyderabad. Afghanistan will turn attention to the one-off Test against Sri Lanka, starting on February 2nd in Colombo. The cricket season continues with plenty of T20 leagues happening across the world. Do keep watching this space for more exciting action. For now, cheers and bye..

 Rohit collects the trophy and hands it over to Rinku. Jaiswal joins Rinku in lofting the trophy behind the champions hoarding. All smiles in the Indian camp and off they go...

 Rohit Sharma: Player of the Match and Indian skipper: I don't remember when was the last time this happened. I think I batted 3 times in one of the IPL games. Creating the partnership was important and we (Rinku and I) kept talking to each other to not lose that intent in big games and it was a good game for us to be in, the pressure was there and was important to bat long and deep and not compromise on the intent we want to show. The last couple of series that he played, he showed what he can do with the bat. Very calm and knows his strength pretty well. He is coming off age and doing what is expected of him and he has done really well for India. Augurs well for the team moving forward, wanted someone like that at the backend and we know what he has done in the IPL and he has carried that to the Indian colors as well.

 Shivam Dube | Player of the Series - 124 runs and 2 wickets from 3 games: As an all-rounder you always want to be the Player of the Series, and this is something new I achieved in my life and it feels really good. We scored a lot of runs on this ground and we thought we would win before the superover, but such is cricket and well done to both teams. There are many things I want to improve, especially in my bowling and I'm trying to get better with each passing game.

 Ibrahim Zadran | Afghanistan skipper: We are happy with the overall performance. We played good cricket, unfortunately we lost in the superover. We got lots of positives from this series and this experience will help us in the upcoming T20 World Cup. The boys gave their best in these 3 games. We never played this kind of cricket in T20, especially against India and in batting department as well. Really happy. We will take some positives from this series and focus on improving a little bit in the T20 World Cup.

 Ravi Bishnoi: The pressure was there, the heartbeat was racing, but I was confident about getting the job done. I was told by the captain that I'll bowl - I knew it wouldn't be easy for them if I bowl back of the length ball, it would be tough to smash on the back-foot. It gives a lot of pleasure to defend during the super overs. I'm happy with the way the ball is leaving my hand. My only thought is to ensure that the batter doesn't get himself used to only one type of delivery, I've worked on my leg-spin in the nets and at the domestic levels.
"""
txt=txt.replace('\n',' ')
txt=txt.replace(' | ',' ')
txt=txt.replace('  ',' ')
txt=txt.lower()

# %%
doc=nlp(txt)

# %%
len(doc)
# Out:
# 842

# %%
doc[1]
# Out:
# hint

# %%
data=[]
for i in range(len(doc)-1):
    data.append(str(doc[i:i+2]))

# %%
data
# Out:
# ['a hint',
#  'hint of',
#  'of controversy',
#  'controversy as',
#  'as we',
#  'we wrap',
#  'wrap up',
#  'up the',
#  'the coverage',
#  'coverage of',
#  'of the',
#  'the 3rd',
#  '3rd t20i',
#  't20i.',
#  '. was',
#  'was rohit',
#  'rohit declared',
#  'declared retired',
#  'retired out',
#  'out /',
#  '/ retired',
#  'retired hurt',
#  'hurt.',
#  '. if',
#  'if it',
#  'it was',
#  'was the',
#  'the former',
#  'former,',
#  ', he',
#  'he could',
#  "couldn't",
#  "n't have",
#  'have come',
#  'come out',
#  'out to',
#  'to bat',
#  'bat for',
#  'for the',
#  'the second',
#  'second time',
#  'time,',
#  ', but',
#  'but is',
#  'is there',
#  'there any',
#  'any ambiguity',
#  'ambiguity in',
#  'in the',
#  'the game',
#  'game that',
#  'that he',
#  'he could',
#  'could have',
#  'have walked',
#  'walked away',
#  'away retired',
#  'retired hurt',
#  'hurt in',
#  'in the',
#  'the first',
#  'first super',
#  'super-',
#  '-over',
#  'over?',
#  '? if',
#  'if so',
#  'so,',
#  ', rohit',
#  'rohit has',
#  'has played',
#  'played the',
#  'the rules',
#  'rules perfectly',
#  'perfectly.',
#  '. a',
#  'a 212',
#  '212 play',
#  'play 212',
#  '212 in',
#  'in the',
#  'the regular',
#  'regular passage',
#  'passage of',
#  'of play',
#  'play.',
#  '. a',
#  'a sublime',
#  'sublime hundred',
#  'hundred from',
#  'from rohit',
#  'rohit after',
#  'after his',
#  'his 2',
#  '2 ducks',
#  'ducks in',
#  'in the',
#  'the first',
#  'first two',
#  'two games',
#  'games.',
#  '. a',
#  'a record',
#  'record 5th',
#  '5th wicket',
#  'wicket partnership',
#  'partnership to',
#  'to haul',
#  'haul india',
#  'india out',
#  'out of',
#  'of choppy',
#  'choppy waters',
#  'waters at',
#  'at 22',
#  '22 for',
#  'for 4',
#  '4.',
#  '. it',
#  'it was',
#  'was followed',
#  'followed by',
#  'by a',
#  'a team',
#  'team batting',
#  'batting display',
#  'display as',
#  'as afghanistan',
#  'afghanistan fought',
#  'fought hard',
#  'hard to',
#  'to drag',
#  'drag the',
#  'the match',
#  'match into',
#  'into a',
#  'a super',
#  'super over',
#  'over.',
#  '. another',
#  'another bit',
#  'bit of',
#  'of controversy',
#  'controversy happened',
#  'happened there',
#  'there with',
#  'with nabi',
#  'nabi happy',
#  'happy to',
#  'to take',
#  'take runs',
#  'runs after',
#  'after a',
#  'a deflection',
#  'deflection off',
#  'off his',
#  'his body',
#  'body,',
#  ', 16',
#  '16 played',
#  'played 16',
#  '16 and',
#  'and we',
#  'we did',
#  "didn't",
#  "n't have",
#  'have a',
#  'a winner',
#  'winner.',
#  '. a',
#  'a second',
#  'second super',
#  'super over',
#  'over was',
#  'was played',
#  'played and',
#  'and we',
#  'we finally',
#  'finally had',
#  'had a',
#  'a winner',
#  'winner for',
#  'for the',
#  'the night',
#  'night.',
#  '. lots',
#  'lots of',
#  'of fours',
#  'fours,',
#  ', sixes',
#  'sixes ,',
#  ', wickets',
#  'wickets and',
#  'and an',
#  'an indian',
#  'indian win',
#  'win to',
#  'to savour',
#  'savour for',
#  'for the',
#  'the crowd',
#  'crowd at',
#  'at the',
#  'the chinnaswamy',
#  'chinnaswamy and',
#  'and we',
#  "we'll",
#  "'ll leave",
#  'leave with',
#  'with only',
#  'only good',
#  'good memories',
#  'memories.',
#  '. india',
#  'india now',
#  'now turn',
#  'turn their',
#  'their attention',
#  'attention towards',
#  'towards red',
#  'red-',
#  '-ball',
#  'ball cricket',
#  'cricket and',
#  'and the',
#  'the 5',
#  '5-',
#  '-match',
#  'match test',
#  'test series',
#  'series against',
#  'against england',
#  'england starts',
#  'starts shortly',
#  'shortly in',
#  'in hyderabad',
#  'hyderabad.',
#  '. afghanistan',
#  'afghanistan will',
#  'will turn',
#  'turn attention',
#  'attention to',
#  'to the',
#  'the one',
#  'one-',
#  '-off',
#  'off test',
#  'test against',
#  'against sri',
#  'sri lanka',
#  'lanka,',
#  ', starting',
#  'starting on',
#  'on february',
#  'february 2nd',
#  '2nd in',
#  'in colombo',
#  'colombo.',
#  '. the',
#  'the cricket',
#  'cricket season',
#  'season continues',
#  'continues with',
#  'with plenty',
#  'plenty of',
#  'of t20',
#  't20 leagues',
#  'leagues happening',
#  'happening across',
#  'across the',
#  'the world',
#  'world.',
#  '. do',
#  'do keep',
#  'keep watching',
#  'watching this',
#  'this space',
#  'space for',
#  'for more',
#  'more exciting',
#  'exciting action',
#  'action.',
#  '. for',
#  'for now',
#  'now,',
#  ', cheers',
#  'cheers and',
#  'and bye',
#  'bye..',
#  '..  ',
#  ' rohit',
#  'rohit collects',
#  'collects the',
#  'the trophy',
#  'trophy and',
#  'and hands',
#  'hands it',
#  'it over',
#  'over to',
#  'to rinku',
#  'rinku.',
#  '. jaiswal',
#  'jaiswal joins',
#  'joins rinku',
#  'rinku in',
#  'in lofting',
#  'lofting the',
#  'the trophy',
#  'trophy behind',
#  'behind the',
#  'the champions',
#  'champions hoarding',
#  'hoarding.',
#  '. all',
#  'all smiles',
#  'smiles in',
#  'in the',
#  'the indian',
#  'indian camp',
#  'camp and',
#  'and off',
#  'off they',
#  'they go',
#  'go...',
#  '...  ',
#  ' rohit',
#  'rohit sharma',
#  'sharma:',
#  ': player',
#  'player of',
#  'of the',
#  'the match',
#  'match and',
#  'and indian',
#  'indian skipper',
#  'skipper:',
#  ': i',
#  'i do',
#  "don't",
#  "n't remember",
#  'remember when',
#  'when was',
#  'was the',
#  'the last',
#  'last time',
#  'time this',
#  'this happened',
#  'happened.',
#  '. i',
#  'i think',
#  'think i',
#  'i batted',
#  'batted 3',
#  '3 times',
#  'times in',
#  'in one',
#  'one of',
#  'of the',
#  'the ipl',
#  'ipl games',
#  'games.',
#  '. creating',
#  'creating the',
#  'the partnership',
#  'partnership was',
#  'was important',
#  'important and',
#  'and we',
#  'we (',
#  '(rinku',
#  'rinku and',
#  'and i',
#  'i)',
#  ') kept',
#  'kept talking',
#  'talking to',
#  'to each',
#  'each other',
#  'other to',
#  'to not',
#  'not lose',
#  'lose that',
#  'that intent',
#  'intent in',
#  'in big',
#  'big games',
#  'games and',
#  'and it',
#  'it was',
#  'was a',
#  'a good',
#  'good game',
#  'game for',
#  'for us',
#  'us to',
#  'to be',
#  'be in',
#  'in,',
#  ', the',
#  'the pressure',
#  'pressure was',
#  'was there',
#  'there and',
#  'and was',
#  'was important',
#  'important to',
#  'to bat',
#  'bat long',
#  'long and',
#  'and deep',
#  'deep and',
#  'and not',
#  'not compromise',
#  'compromise on',
#  'on the',
#  'the intent',
#  'intent we',
#  'we want',
#  'want to',
#  'to show',
#  'show.',
#  '. the',
#  'the last',
#  'last couple',
#  'couple of',
#  'of series',
#  'series that',
#  'that he',
#  'he played',
#  'played,',
#  ', he',
#  'he showed',
#  'showed what',
#  'what he',
#  'he can',
#  'can do',
#  'do with',
#  'with the',
#  'the bat',
#  'bat.',
#  '. very',
#  'very calm',
#  'calm and',
#  'and knows',
#  'knows his',
#  'his strength',
#  'strength pretty',
#  'pretty well',
#  'well.',
#  '. he',
#  'he is',
#  'is coming',
#  'coming off',
#  'off age',
#  'age and',
#  'and doing',
#  'doing what',
#  'what is',
#  'is expected',
#  'expected of',
#  'of him',
#  'him and',
#  'and he',
#  'he has',
#  'has done',
#  'done really',
#  'really well',
#  'well for',
#  'for india',
#  'india.',
#  '. augurs',
#  'augurs well',
#  'well for',
#  'for the',
#  'the team',
#  'team moving',
#  'moving forward',
#  'forward,',
#  ', wanted',
#  'wanted someone',
#  'someone like',
#  'like that',
#  'that at',
#  'at the',
#  'the backend',
#  'backend and',
#  'and we',
#  'we know',
#  'know what',
#  'what he',
#  'he has',
#  'has done',
#  'done in',
#  'in the',
#  'the ipl',
#  'ipl and',
#  'and he',
#  'he has',
#  'has carried',
#  'carried that',
#  'that to',
#  'to the',
#  'the indian',
#  'indian colors',
#  'colors as',
#  'as well',
#  'well.',
#  '.  ',
#  ' shivam',
#  'shivam dube',
#  'dube player',
#  'player of',
#  'of the',
#  'the series',
#  'series -',
#  '- 124',
#  '124 runs',
#  'runs and',
#  'and 2',
#  '2 wickets',
#  'wickets from',
#  'from 3',
#  '3 games',
#  'games:',
#  ': as',
#  'as an',
#  'an all',
#  'all-',
#  '-rounder',
#  'rounder you',
#  'you always',
#  'always want',
#  'want to',
#  'to be',
#  'be the',
#  'the player',
#  'player of',
#  'of the',
#  'the series',
#  'series,',
#  ', and',
#  'and this',
#  'this is',
#  'is something',
#  'something new',
#  'new i',
#  'i achieved',
#  'achieved in',
#  'in my',
#  'my life',
#  'life and',
#  'and it',
#  'it feels',
#  'feels really',
#  'really good',
#  'good.',
#  '. we',
#  'we scored',
#  'scored a',
#  'a lot',
#  'lot of',
#  'of runs',
#  'runs on',
#  'on this',
#  'this ground',
#  'ground and',
#  'and we',
#  'we thought',
#  'thought we',
#  'we would',
#  'would win',
#  'win before',
#  'before the',
#  'the superover',
#  'superover,',
#  ', but',
#  'but such',
#  'such is',
#  'is cricket',
#  'cricket and',
#  'and well',
#  'well done',
#  'done to',
#  'to both',
#  'both teams',
#  'teams.',
#  '. there',
#  'there are',
#  'are many',
#  'many things',
#  'things i',
#  'i want',
#  'want to',
#  'to improve',
#  'improve,',
#  ', especially',
#  'especially in',
#  'in my',
#  'my bowling',
#  'bowling and',
#  'and i',
#  "i'm",
#  "'m trying",
#  'trying to',
#  'to get',
#  'get better',
#  'better with',
#  'with each',
#  'each passing',
#  'passing game',
#  'game.',
#  '.  ',
#  ' ibrahim',
#  'ibrahim zadran',
#  'zadran afghanistan',
#  'afghanistan skipper',
#  'skipper:',
#  ': we',
#  'we are',
#  'are happy',
#  'happy with',
#  'with the',
#  'the overall',
#  'overall performance',
#  'performance.',
#  '. we',
#  'we played',
#  'played good',
#  'good cricket',
#  'cricket,',
#  ', unfortunately',
#  'unfortunately we',
#  'we lost',
#  'lost in',
#  'in the',
#  'the superover',
#  'superover.',
#  '. we',
#  'we got',
#  'got lots',
#  'lots of',
#  'of positives',
#  'positives from',
#  'from this',
#  'this series',
#  'series and',
#  'and this',
#  'this experience',
#  'experience will',
#  'will help',
#  'help us',
#  'us in',
#  'in the',
#  'the upcoming',
#  'upcoming t20',
#  't20 world',
#  'world cup',
#  'cup.',
#  '. the',
#  'the boys',
#  'boys gave',
#  'gave their',
#  'their best',
#  'best in',
#  'in these',
#  'these 3',
#  '3 games',
#  'games.',
#  '. we',
#  'we never',
#  'never played',
#  'played this',
#  'this kind',
#  'kind of',
#  'of cricket',
#  'cricket in',
#  'in t20',
#  't20,',
#  ', especially',
#  'especially against',
#  'against india',
#  'india and',
#  'and in',
#  'in batting',
#  'batting department',
#  'department as',
#  'as well',
#  'well.',
#  '. really',
#  'really happy',
#  'happy.',
#  '. we',
#  'we will',
#  'will take',
#  'take some',
#  'some positives',
#  'positives from',
#  'from this',
#  'this series',
#  'series and',
#  'and focus',
#  'focus on',
#  'on improving',
#  'improving a',
#  'a little',
#  'little bit',
#  'bit in',
#  'in the',
#  'the t20',
#  't20 world',
#  'world cup',
#  'cup.',
#  '.  ',
#  ' ravi',
#  'ravi bishnoi',
#  'bishnoi:',
#  ': the',
#  'the pressure',
#  'pressure was',
#  'was there',
#  'there,',
#  ', the',
#  'the heartbeat',
#  'heartbeat was',
#  'was racing',
#  'racing,',
#  ', but',
#  'but i',
#  'i was',
#  'was confident',
#  'confident about',
#  'about getting',
#  'getting the',
#  'the job',
#  'job done',
#  'done.',
#  '. i',
#  'i was',
#  'was told',
#  'told by',
#  'by the',
#  'the captain',
#  'captain that',
#  'that i',
#  "i'll",
#  "'ll bowl",
#  'bowl -',
#  '- i',
#  'i knew',
#  'knew it',
#  'it would',
#  "wouldn't",
#  "n't be",
#  'be easy',
#  'easy for',
#  'for them',
#  'them if',
#  'if i',
#  'i bowl',
#  'bowl back',
#  'back of',
#  'of the',
#  'the length',
#  'length ball',
#  'ball,',
#  ', it',
#  'it would',
#  'would be',
#  'be tough',
#  'tough to',
#  'to smash',
#  'smash on',
#  'on the',
#  'the back',
#  'back-',
#  '-foot',
#  'foot.',
#  '. it',
#  'it gives',
#  'gives a',
#  'a lot',
#  'lot of',
#  'of pleasure',
#  'pleasure to',
#  'to defend',
#  'defend during',
#  'during the',
#  'the super',
#  'super overs',
#  'overs.',
#  '. i',
#  "i'm",
#  "'m happy",
#  'happy with',
#  'with the',
#  'the way',
#  'way the',
#  'the ball',
#  'ball is',
#  'is leaving',
#  'leaving my',
#  'my hand',
#  'hand.',
#  '. my',
#  'my only',
#  'only thought',
#  'thought is',
#  'is to',
#  'to ensure',
#  'ensure that',
#  'that the',
#  'the batter',
#  'batter does',
#  "doesn't",
#  "n't get",
#  'get himself',
#  'himself used',
#  'used to',
#  'to only',
#  'only one',
#  'one type',
#  'type of',
#  'of delivery',
#  'delivery,',
#  ', i',
#  "i've",
#  "'ve worked",
#  'worked on',
#  'on my',
#  'my leg',
#  'leg-',
#  '-spin',
#  'spin in',
#  'in the',
#  'the nets',
#  'nets and',
#  'and at',
#  'at the',
#  'the domestic',
#  'domestic levels',
#  'levels.']

# %%
len(data)
# Out:
# 841

# %%
data.count('a hint')
# Out:
# 1

# %%
unique_pairs=list(set(data))

# %%
len(unique_pairs)
# Out:
# 733

# %% [markdown]
# ### Occurance probability

# %%
prob_dist=[]
for pair in tqdm(unique_pairs):
    prob_dist.append([pair,data.count(pair)])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 733/733 [00:00<00:00, 52348.46it/s]

# %%
#other method
a=np.array(data)
pair,count=np.unique(a,return_counts=True)

# %%
count.max()
# Out:
# 10

# %%
count.min()
# Out:
# 1

# %%
pair
# Out:
# array([' ibrahim', ' ravi', ' rohit', ' shivam', "'ll bowl", "'ll leave",
#        "'m happy", "'m trying", "'ve worked", '(rinku', ') kept', ', 16',
#        ', and', ', but', ', cheers', ', especially', ', he', ', i',
#        ', it', ', rohit', ', sixes', ', starting', ', the',
#        ', unfortunately', ', wanted', ', wickets', '- 124', '- i',
#        '-ball', '-foot', '-match', '-off', '-over', '-rounder', '-spin',
#        '.  ', '. a', '. afghanistan', '. all', '. another', '. augurs',
#        '. creating', '. do', '. for', '. he', '. i', '. if', '. india',
#        '. it', '. jaiswal', '. lots', '. my', '. really', '. the',
#        '. there', '. very', '. was', '. we', '..  ', '...  ', '/ retired',
#        '124 runs', '16 and', '16 played', '2 ducks', '2 wickets',
#        '212 in', '212 play', '22 for', '2nd in', '3 games', '3 times',
#        '3rd t20i', '4.', '5-', '5th wicket', ': as', ': i', ': player',
#        ': the', ': we', '? if', 'a 212', 'a deflection', 'a good',
#        'a hint', 'a little', 'a lot', 'a record', 'a second', 'a sublime',
#        'a super', 'a team', 'a winner', 'about getting', 'achieved in',
#        'across the', 'action.', 'afghanistan fought',
#        'afghanistan skipper', 'afghanistan will', 'after a', 'after his',
#        'against england', 'against india', 'against sri', 'age and',
#        'all smiles', 'all-', 'always want', 'ambiguity in', 'an all',
#        'an indian', 'and 2', 'and an', 'and at', 'and bye', 'and deep',
#        'and doing', 'and focus', 'and hands', 'and he', 'and i', 'and in',
#        'and indian', 'and it', 'and knows', 'and not', 'and off',
#        'and the', 'and this', 'and was', 'and we', 'and well',
#        'another bit', 'any ambiguity', 'are happy', 'are many',
#        'as afghanistan', 'as an', 'as we', 'as well', 'at 22', 'at the',
#        'attention to', 'attention towards', 'augurs well', 'away retired',
#        'back of', 'back-', 'backend and', 'ball cricket', 'ball is',
#        'ball,', 'bat for', 'bat long', 'bat.', 'batted 3', 'batter does',
#        'batting department', 'batting display', 'be easy', 'be in',
#        'be the', 'be tough', 'before the', 'behind the', 'best in',
#        'better with', 'big games', 'bishnoi:', 'bit in', 'bit of',
#        'body,', 'both teams', 'bowl -', 'bowl back', 'bowling and',
#        'boys gave', 'but i', 'but is', 'but such', 'by a', 'by the',
#        'bye..', 'calm and', 'camp and', 'can do', 'captain that',
#        'carried that', 'champions hoarding', 'cheers and',
#        'chinnaswamy and', 'choppy waters', 'collects the', 'colombo.',
#        'colors as', 'come out', 'coming off', 'compromise on',
#        'confident about', 'continues with', 'controversy as',
#        'controversy happened', 'could have', "couldn't", 'couple of',
#        'coverage of', 'creating the', 'cricket and', 'cricket in',
#        'cricket season', 'cricket,', 'crowd at', 'cup.',
#        'declared retired', 'deep and', 'defend during', 'deflection off',
#        'delivery,', 'department as', "didn't", 'display as', 'do keep',
#        'do with', "doesn't", 'doing what', 'domestic levels', "don't",
#        'done in', 'done really', 'done to', 'done.', 'drag the',
#        'dube player', 'ducks in', 'during the', 'each other',
#        'each passing', 'easy for', 'england starts', 'ensure that',
#        'especially against', 'especially in', 'exciting action',
#        'expected of', 'experience will', 'february 2nd', 'feels really',
#        'finally had', 'first super', 'first two', 'focus on',
#        'followed by', 'foot.', 'for 4', 'for india', 'for more',
#        'for now', 'for the', 'for them', 'for us', 'former,', 'forward,',
#        'fought hard', 'fours,', 'from 3', 'from rohit', 'from this',
#        'game for', 'game that', 'game.', 'games and', 'games.', 'games:',
#        'gave their', 'get better', 'get himself', 'getting the',
#        'gives a', 'go...', 'good cricket', 'good game', 'good memories',
#        'good.', 'got lots', 'ground and', 'had a', 'hand.', 'hands it',
#        'happened there', 'happened.', 'happening across', 'happy to',
#        'happy with', 'happy.', 'hard to', 'has carried', 'has done',
#        'has played', 'haul india', 'have a', 'have come', 'have walked',
#        'he can', 'he could', 'he has', 'he is', 'he played', 'he showed',
#        'heartbeat was', 'help us', 'him and', 'himself used', 'hint of',
#        'his 2', 'his body', 'his strength', 'hoarding.', 'hundred from',
#        'hurt in', 'hurt.', 'hyderabad.', 'i achieved', 'i batted',
#        'i bowl', 'i do', 'i knew', 'i think', 'i want', 'i was', "i'll",
#        "i'm", "i've", 'i)', 'ibrahim zadran', 'if i', 'if it', 'if so',
#        'important and', 'important to', 'improve,', 'improving a',
#        'in batting', 'in big', 'in colombo', 'in hyderabad', 'in lofting',
#        'in my', 'in one', 'in t20', 'in the', 'in these', 'in,',
#        'india and', 'india now', 'india out', 'india.', 'indian camp',
#        'indian colors', 'indian skipper', 'indian win', 'intent in',
#        'intent we', 'into a', 'ipl and', 'ipl games', 'is coming',
#        'is cricket', 'is expected', 'is leaving', 'is something',
#        'is there', 'is to', 'it feels', 'it gives', 'it over', 'it was',
#        'it would', 'jaiswal joins', 'job done', 'joins rinku',
#        'keep watching', 'kept talking', 'kind of', 'knew it', 'know what',
#        'knows his', 'lanka,', 'last couple', 'last time',
#        'leagues happening', 'leave with', 'leaving my', 'leg-',
#        'length ball', 'levels.', 'life and', 'like that', 'little bit',
#        'lofting the', 'long and', 'lose that', 'lost in', 'lot of',
#        'lots of', 'many things', 'match and', 'match into', 'match test',
#        'memories.', 'more exciting', 'moving forward', 'my bowling',
#        'my hand', 'my leg', 'my life', 'my only', "n't be", "n't get",
#        "n't have", "n't remember", 'nabi happy', 'nets and',
#        'never played', 'new i', 'night.', 'not compromise', 'not lose',
#        'now turn', 'now,', 'of choppy', 'of controversy', 'of cricket',
#        'of delivery', 'of fours', 'of him', 'of play', 'of pleasure',
#        'of positives', 'of runs', 'of series', 'of t20', 'of the',
#        'off age', 'off his', 'off test', 'off they', 'on february',
#        'on improving', 'on my', 'on the', 'on this', 'one of', 'one type',
#        'one-', 'only good', 'only one', 'only thought', 'other to',
#        'out /', 'out of', 'out to', 'over to', 'over was', 'over.',
#        'over?', 'overall performance', 'overs.', 'partnership to',
#        'partnership was', 'passage of', 'passing game', 'perfectly.',
#        'performance.', 'play 212', 'play.', 'played 16', 'played and',
#        'played good', 'played the', 'played this', 'played,', 'player of',
#        'pleasure to', 'plenty of', 'positives from', 'pressure was',
#        'pretty well', 'racing,', 'ravi bishnoi', 'really good',
#        'really happy', 'really well', 'record 5th', 'red-',
#        'regular passage', 'remember when', 'retired hurt', 'retired out',
#        'rinku and', 'rinku in', 'rinku.', 'rohit after', 'rohit collects',
#        'rohit declared', 'rohit has', 'rohit sharma', 'rounder you',
#        'rules perfectly', 'runs after', 'runs and', 'runs on',
#        'savour for', 'scored a', 'season continues', 'second super',
#        'second time', 'series -', 'series against', 'series and',
#        'series that', 'series,', 'sharma:', 'shivam dube', 'shortly in',
#        'show.', 'showed what', 'sixes ,', 'skipper:', 'smash on',
#        'smiles in', 'so,', 'some positives', 'someone like',
#        'something new', 'space for', 'spin in', 'sri lanka',
#        'starting on', 'starts shortly', 'strength pretty',
#        'sublime hundred', 'such is', 'super over', 'super overs',
#        'super-', 'superover,', 'superover.', 't20 leagues', 't20 world',
#        't20,', 't20i.', 'take runs', 'take some', 'talking to',
#        'team batting', 'team moving', 'teams.', 'test against',
#        'test series', 'that at', 'that he', 'that i', 'that intent',
#        'that the', 'that to', 'the 3rd', 'the 5', 'the back',
#        'the backend', 'the ball', 'the bat', 'the batter', 'the boys',
#        'the captain', 'the champions', 'the chinnaswamy', 'the coverage',
#        'the cricket', 'the crowd', 'the domestic', 'the first',
#        'the former', 'the game', 'the heartbeat', 'the indian',
#        'the intent', 'the ipl', 'the job', 'the last', 'the length',
#        'the match', 'the nets', 'the night', 'the one', 'the overall',
#        'the partnership', 'the player', 'the pressure', 'the regular',
#        'the rules', 'the second', 'the series', 'the super',
#        'the superover', 'the t20', 'the team', 'the trophy',
#        'the upcoming', 'the way', 'the world', 'their attention',
#        'their best', 'them if', 'there and', 'there any', 'there are',
#        'there with', 'there,', 'these 3', 'they go', 'things i',
#        'think i', 'this experience', 'this ground', 'this happened',
#        'this is', 'this kind', 'this series', 'this space', 'thought is',
#        'thought we', 'time this', 'time,', 'times in', 'to bat', 'to be',
#        'to both', 'to defend', 'to drag', 'to each', 'to ensure',
#        'to get', 'to haul', 'to improve', 'to not', 'to only', 'to rinku',
#        'to savour', 'to show', 'to smash', 'to take', 'to the', 'told by',
#        'tough to', 'towards red', 'trophy and', 'trophy behind',
#        'trying to', 'turn attention', 'turn their', 'two games',
#        'type of', 'unfortunately we', 'up the', 'upcoming t20', 'us in',
#        'us to', 'used to', 'very calm', 'walked away', 'want to',
#        'wanted someone', 'was a', 'was confident', 'was followed',
#        'was important', 'was played', 'was racing', 'was rohit',
#        'was the', 'was there', 'was told', 'watching this', 'waters at',
#        'way the', 'we (', 'we are', 'we did', 'we finally', 'we got',
#        'we know', 'we lost', 'we never', 'we played', 'we scored',
#        'we thought', 'we want', 'we will', 'we would', 'we wrap', "we'll",
#        'well done', 'well for', 'well.', 'what he', 'what is', 'when was',
#        'wicket partnership', 'wickets and', 'wickets from', 'will help',
#        'will take', 'will turn', 'win before', 'win to', 'winner for',
#        'winner.', 'with each', 'with nabi', 'with only', 'with plenty',
#        'with the', 'worked on', 'world cup', 'world.', 'would be',
#        'would win', "wouldn't", 'wrap up', 'you always',
#        'zadran afghanistan'], dtype='<U20')

# %%
pair[0].split(' ')[-1]
# Out:
# 'ibrahim'

# %%
len(pair[0].split(' '))
# Out:
# 2

# %%
prob_dist=[]
for i in range(len(pair)):
    prob_dist.append([pair[i],count[i],pair[i].split(' ')[-1]])

# %%
prob_dist
# Out:
# [[' ibrahim', 1, 'ibrahim'],
#  [' ravi', 1, 'ravi'],
#  [' rohit', 2, 'rohit'],
#  [' shivam', 1, 'shivam'],
#  ["'ll bowl", 1, 'bowl'],
#  ["'ll leave", 1, 'leave'],
#  ["'m happy", 1, 'happy'],
#  ["'m trying", 1, 'trying'],
#  ["'ve worked", 1, 'worked'],
#  ['(rinku', 1, '(rinku'],
#  [') kept', 1, 'kept'],
#  [', 16', 1, '16'],
#  [', and', 1, 'and'],
#  [', but', 3, 'but'],
#  [', cheers', 1, 'cheers'],
#  [', especially', 2, 'especially'],
#  [', he', 2, 'he'],
#  [', i', 1, 'i'],
#  [', it', 1, 'it'],
#  [', rohit', 1, 'rohit'],
#  [', sixes', 1, 'sixes'],
#  [', starting', 1, 'starting'],
#  [', the', 2, 'the'],
#  [', unfortunately', 1, 'unfortunately'],
#  [', wanted', 1, 'wanted'],
#  [', wickets', 1, 'wickets'],
#  ['- 124', 1, '124'],
#  ['- i', 1, 'i'],
#  ['-ball', 1, '-ball'],
#  ['-foot', 1, '-foot'],
#  ['-match', 1, '-match'],
#  ['-off', 1, '-off'],
#  ['-over', 1, '-over'],
#  ['-rounder', 1, '-rounder'],
#  ['-spin', 1, '-spin'],
#  ['.  ', 3, ''],
#  ['. a', 4, 'a'],
#  ['. afghanistan', 1, 'afghanistan'],
#  ['. all', 1, 'all'],
#  ['. another', 1, 'another'],
#  ['. augurs', 1, 'augurs'],
#  ['. creating', 1, 'creating'],
#  ['. do', 1, 'do'],
#  ['. for', 1, 'for'],
#  ['. he', 1, 'he'],
#  ['. i', 3, 'i'],
#  ['. if', 1, 'if'],
#  ['. india', 1, 'india'],
#  ['. it', 2, 'it'],
#  ['. jaiswal', 1, 'jaiswal'],
#  ['. lots', 1, 'lots'],
#  ['. my', 1, 'my'],
#  ['. really', 1, 'really'],
#  ['. the', 3, 'the'],
#  ['. there', 1, 'there'],
#  ['. very', 1, 'very'],
#  ['. was', 1, 'was'],
#  ['. we', 5, 'we'],
#  ['..  ', 1, ''],
#  ['...  ', 1, ''],
#  ['/ retired', 1, 'retired'],
#  ['124 runs', 1, 'runs'],
#  ['16 and', 1, 'and'],
#  ['16 played', 1, 'played'],
#  ['2 ducks', 1, 'ducks'],
#  ['2 wickets', 1, 'wickets'],
#  ['212 in', 1, 'in'],
#  ['212 play', 1, 'play'],
#  ['22 for', 1, 'for'],
#  ['2nd in', 1, 'in'],
#  ['3 games', 2, 'games'],
#  ['3 times', 1, 'times'],
#  ['3rd t20i', 1, 't20i'],
#  ['4.', 1, '4.'],
#  ['5-', 1, '5-'],
#  ['5th wicket', 1, 'wicket'],
#  [': as', 1, 'as'],
#  [': i', 1, 'i'],
#  [': player', 1, 'player'],
#  [': the', 1, 'the'],
#  [': we', 1, 'we'],
#  ['? if', 1, 'if'],
#  ['a 212', 1, '212'],
#  ['a deflection', 1, 'deflection'],
#  ['a good', 1, 'good'],
#  ['a hint', 1, 'hint'],
#  ['a little', 1, 'little'],
#  ['a lot', 2, 'lot'],
#  ['a record', 1, 'record'],
#  ['a second', 1, 'second'],
#  ['a sublime', 1, 'sublime'],
#  ['a super', 1, 'super'],
#  ['a team', 1, 'team'],
#  ['a winner', 2, 'winner'],
#  ['about getting', 1, 'getting'],
#  ['achieved in', 1, 'in'],
#  ['across the', 1, 'the'],
#  ['action.', 1, 'action.'],
#  ['afghanistan fought', 1, 'fought'],
#  ['afghanistan skipper', 1, 'skipper'],
#  ['afghanistan will', 1, 'will'],
#  ['after a', 1, 'a'],
#  ['after his', 1, 'his'],
#  ['against england', 1, 'england'],
#  ['against india', 1, 'india'],
#  ['against sri', 1, 'sri'],
#  ['age and', 1, 'and'],
#  ['all smiles', 1, 'smiles'],
#  ['all-', 1, 'all-'],
#  ['always want', 1, 'want'],
#  ['ambiguity in', 1, 'in'],
#  ['an all', 1, 'all'],
#  ['an indian', 1, 'indian'],
#  ['and 2', 1, '2'],
#  ['and an', 1, 'an'],
#  ['and at', 1, 'at'],
#  ['and bye', 1, 'bye'],
#  ['and deep', 1, 'deep'],
#  ['and doing', 1, 'doing'],
#  ['and focus', 1, 'focus'],
#  ['and hands', 1, 'hands'],
#  ['and he', 2, 'he'],
#  ['and i', 2, 'i'],
#  ['and in', 1, 'in'],
#  ['and indian', 1, 'indian'],
#  ['and it', 2, 'it'],
#  ['and knows', 1, 'knows'],
#  ['and not', 1, 'not'],
#  ['and off', 1, 'off'],
#  ['and the', 1, 'the'],
#  ['and this', 2, 'this'],
#  ['and was', 1, 'was'],
#  ['and we', 6, 'we'],
#  ['and well', 1, 'well'],
#  ['another bit', 1, 'bit'],
#  ['any ambiguity', 1, 'ambiguity'],
#  ['are happy', 1, 'happy'],
#  ['are many', 1, 'many'],
#  ['as afghanistan', 1, 'afghanistan'],
#  ['as an', 1, 'an'],
#  ['as we', 1, 'we'],
#  ['as well', 2, 'well'],
#  ['at 22', 1, '22'],
#  ['at the', 3, 'the'],
#  ['attention to', 1, 'to'],
#  ['attention towards', 1, 'towards'],
#  ['augurs well', 1, 'well'],
#  ['away retired', 1, 'retired'],
#  ['back of', 1, 'of'],
#  ['back-', 1, 'back-'],
#  ['backend and', 1, 'and'],
#  ['ball cricket', 1, 'cricket'],
#  ['ball is', 1, 'is'],
#  ['ball,', 1, 'ball,'],
#  ['bat for', 1, 'for'],
#  ['bat long', 1, 'long'],
#  ['bat.', 1, 'bat.'],
#  ['batted 3', 1, '3'],
#  ['batter does', 1, 'does'],
#  ['batting department', 1, 'department'],
#  ['batting display', 1, 'display'],
#  ['be easy', 1, 'easy'],
#  ['be in', 1, 'in'],
#  ['be the', 1, 'the'],
#  ['be tough', 1, 'tough'],
#  ['before the', 1, 'the'],
#  ['behind the', 1, 'the'],
#  ['best in', 1, 'in'],
#  ['better with', 1, 'with'],
#  ['big games', 1, 'games'],
#  ['bishnoi:', 1, 'bishnoi:'],
#  ['bit in', 1, 'in'],
#  ['bit of', 1, 'of'],
#  ['body,', 1, 'body,'],
#  ['both teams', 1, 'teams'],
#  ['bowl -', 1, '-'],
#  ['bowl back', 1, 'back'],
#  ['bowling and', 1, 'and'],
#  ['boys gave', 1, 'gave'],
#  ['but i', 1, 'i'],
#  ['but is', 1, 'is'],
#  ['but such', 1, 'such'],
#  ['by a', 1, 'a'],
#  ['by the', 1, 'the'],
#  ['bye..', 1, 'bye..'],
#  ['calm and', 1, 'and'],
#  ['camp and', 1, 'and'],
#  ['can do', 1, 'do'],
#  ['captain that', 1, 'that'],
#  ['carried that', 1, 'that'],
#  ['champions hoarding', 1, 'hoarding'],
#  ['cheers and', 1, 'and'],
#  ['chinnaswamy and', 1, 'and'],
#  ['choppy waters', 1, 'waters'],
#  ['collects the', 1, 'the'],
#  ['colombo.', 1, 'colombo.'],
#  ['colors as', 1, 'as'],
#  ['come out', 1, 'out'],
#  ['coming off', 1, 'off'],
#  ['compromise on', 1, 'on'],
#  ['confident about', 1, 'about'],
#  ['continues with', 1, 'with'],
#  ['controversy as', 1, 'as'],
#  ['controversy happened', 1, 'happened'],
#  ['could have', 1, 'have'],
#  ["couldn't", 1, "couldn't"],
#  ['couple of', 1, 'of'],
#  ['coverage of', 1, 'of'],
#  ['creating the', 1, 'the'],
#  ['cricket and', 2, 'and'],
#  ['cricket in', 1, 'in'],
#  ['cricket season', 1, 'season'],
#  ['cricket,', 1, 'cricket,'],
#  ['crowd at', 1, 'at'],
#  ['cup.', 2, 'cup.'],
#  ['declared retired', 1, 'retired'],
#  ['deep and', 1, 'and'],
#  ['defend during', 1, 'during'],
#  ['deflection off', 1, 'off'],
#  ['delivery,', 1, 'delivery,'],
#  ['department as', 1, 'as'],
#  ["didn't", 1, "didn't"],
#  ['display as', 1, 'as'],
#  ['do keep', 1, 'keep'],
#  ['do with', 1, 'with'],
#  ["doesn't", 1, "doesn't"],
#  ['doing what', 1, 'what'],
#  ['domestic levels', 1, 'levels'],
#  ["don't", 1, "don't"],
#  ['done in', 1, 'in'],
#  ['done really', 1, 'really'],
#  ['done to', 1, 'to'],
#  ['done.', 1, 'done.'],
#  ['drag the', 1, 'the'],
#  ['dube player', 1, 'player'],
#  ['ducks in', 1, 'in'],
#  ['during the', 1, 'the'],
#  ['each other', 1, 'other'],
#  ['each passing', 1, 'passing'],
#  ['easy for', 1, 'for'],
#  ['england starts', 1, 'starts'],
#  ['ensure that', 1, 'that'],
#  ['especially against', 1, 'against'],
#  ['especially in', 1, 'in'],
#  ['exciting action', 1, 'action'],
#  ['expected of', 1, 'of'],
#  ['experience will', 1, 'will'],
#  ['february 2nd', 1, '2nd'],
#  ['feels really', 1, 'really'],
#  ['finally had', 1, 'had'],
#  ['first super', 1, 'super'],
#  ['first two', 1, 'two'],
#  ['focus on', 1, 'on'],
#  ['followed by', 1, 'by'],
#  ['foot.', 1, 'foot.'],
#  ['for 4', 1, '4'],
#  ['for india', 1, 'india'],
#  ['for more', 1, 'more'],
#  ['for now', 1, 'now'],
#  ['for the', 4, 'the'],
#  ['for them', 1, 'them'],
#  ['for us', 1, 'us'],
#  ['former,', 1, 'former,'],
#  ['forward,', 1, 'forward,'],
#  ['fought hard', 1, 'hard'],
#  ['fours,', 1, 'fours,'],
#  ['from 3', 1, '3'],
#  ['from rohit', 1, 'rohit'],
#  ['from this', 2, 'this'],
#  ['game for', 1, 'for'],
#  ['game that', 1, 'that'],
#  ['game.', 1, 'game.'],
#  ['games and', 1, 'and'],
#  ['games.', 3, 'games.'],
#  ['games:', 1, 'games:'],
#  ['gave their', 1, 'their'],
#  ['get better', 1, 'better'],
#  ['get himself', 1, 'himself'],
#  ['getting the', 1, 'the'],
#  ['gives a', 1, 'a'],
#  ['go...', 1, 'go...'],
#  ['good cricket', 1, 'cricket'],
#  ['good game', 1, 'game'],
#  ['good memories', 1, 'memories'],
#  ['good.', 1, 'good.'],
#  ['got lots', 1, 'lots'],
#  ['ground and', 1, 'and'],
#  ['had a', 1, 'a'],
#  ['hand.', 1, 'hand.'],
#  ['hands it', 1, 'it'],
#  ['happened there', 1, 'there'],
#  ['happened.', 1, 'happened.'],
#  ['happening across', 1, 'across'],
#  ['happy to', 1, 'to'],
#  ['happy with', 2, 'with'],
#  ['happy.', 1, 'happy.'],
#  ['hard to', 1, 'to'],
#  ['has carried', 1, 'carried'],
#  ['has done', 2, 'done'],
#  ['has played', 1, 'played'],
#  ['haul india', 1, 'india'],
#  ['have a', 1, 'a'],
#  ['have come', 1, 'come'],
#  ['have walked', 1, 'walked'],
#  ['he can', 1, 'can'],
#  ['he could', 2, 'could'],
#  ['he has', 3, 'has'],
#  ['he is', 1, 'is'],
#  ['he played', 1, 'played'],
#  ['he showed', 1, 'showed'],
#  ['heartbeat was', 1, 'was'],
#  ['help us', 1, 'us'],
#  ['him and', 1, 'and'],
#  ['himself used', 1, 'used'],
#  ['hint of', 1, 'of'],
#  ['his 2', 1, '2'],
#  ['his body', 1, 'body'],
#  ['his strength', 1, 'strength'],
#  ['hoarding.', 1, 'hoarding.'],
#  ['hundred from', 1, 'from'],
#  ['hurt in', 1, 'in'],
#  ['hurt.', 1, 'hurt.'],
#  ['hyderabad.', 1, 'hyderabad.'],
#  ['i achieved', 1, 'achieved'],
#  ['i batted', 1, 'batted'],
#  ['i bowl', 1, 'bowl'],
#  ['i do', 1, 'do'],
#  ['i knew', 1, 'knew'],
#  ['i think', 1, 'think'],
#  ['i want', 1, 'want'],
#  ['i was', 2, 'was'],
#  ["i'll", 1, "i'll"],
#  ["i'm", 2, "i'm"],
#  ["i've", 1, "i've"],
#  ['i)', 1, 'i)'],
#  ['ibrahim zadran', 1, 'zadran'],
#  ['if i', 1, 'i'],
#  ['if it', 1, 'it'],
#  ['if so', 1, 'so'],
#  ['important and', 1, 'and'],
#  ['important to', 1, 'to'],
#  ['improve,', 1, 'improve,'],
#  ['improving a', 1, 'a'],
#  ['in batting', 1, 'batting'],
#  ['in big', 1, 'big'],
#  ['in colombo', 1, 'colombo'],
#  ['in hyderabad', 1, 'hyderabad'],
#  ['in lofting', 1, 'lofting'],
#  ['in my', 2, 'my'],
#  ['in one', 1, 'one'],
#  ['in t20', 1, 't20'],
#  ['in the', 10, 'the'],
#  ['in these', 1, 'these'],
#  ['in,', 1, 'in,'],
#  ['india and', 1, 'and'],
#  ['india now', 1, 'now'],
#  ['india out', 1, 'out'],
#  ['india.', 1, 'india.'],
#  ['indian camp', 1, 'camp'],
#  ['indian colors', 1, 'colors'],
#  ['indian skipper', 1, 'skipper'],
#  ['indian win', 1, 'win'],
#  ['intent in', 1, 'in'],
#  ['intent we', 1, 'we'],
#  ['into a', 1, 'a'],
#  ['ipl and', 1, 'and'],
#  ['ipl games', 1, 'games'],
#  ['is coming', 1, 'coming'],
#  ['is cricket', 1, 'cricket'],
#  ['is expected', 1, 'expected'],
#  ['is leaving', 1, 'leaving'],
#  ['is something', 1, 'something'],
#  ['is there', 1, 'there'],
#  ['is to', 1, 'to'],
#  ['it feels', 1, 'feels'],
#  ['it gives', 1, 'gives'],
#  ['it over', 1, 'over'],
#  ['it was', 3, 'was'],
#  ['it would', 2, 'would'],
#  ['jaiswal joins', 1, 'joins'],
#  ['job done', 1, 'done'],
#  ['joins rinku', 1, 'rinku'],
#  ['keep watching', 1, 'watching'],
#  ['kept talking', 1, 'talking'],
#  ['kind of', 1, 'of'],
#  ['knew it', 1, 'it'],
#  ['know what', 1, 'what'],
#  ['knows his', 1, 'his'],
#  ['lanka,', 1, 'lanka,'],
#  ['last couple', 1, 'couple'],
#  ['last time', 1, 'time'],
#  ['leagues happening', 1, 'happening'],
#  ['leave with', 1, 'with'],
#  ['leaving my', 1, 'my'],
#  ['leg-', 1, 'leg-'],
#  ['length ball', 1, 'ball'],
#  ['levels.', 1, 'levels.'],
#  ['life and', 1, 'and'],
#  ['like that', 1, 'that'],
#  ['little bit', 1, 'bit'],
#  ['lofting the', 1, 'the'],
#  ['long and', 1, 'and'],
#  ['lose that', 1, 'that'],
#  ['lost in', 1, 'in'],
#  ['lot of', 2, 'of'],
#  ['lots of', 2, 'of'],
#  ['many things', 1, 'things'],
#  ['match and', 1, 'and'],
#  ['match into', 1, 'into'],
#  ['match test', 1, 'test'],
#  ['memories.', 1, 'memories.'],
#  ['more exciting', 1, 'exciting'],
#  ['moving forward', 1, 'forward'],
#  ['my bowling', 1, 'bowling'],
#  ['my hand', 1, 'hand'],
#  ['my leg', 1, 'leg'],
#  ['my life', 1, 'life'],
#  ['my only', 1, 'only'],
#  ["n't be", 1, 'be'],
#  ["n't get", 1, 'get'],
#  ["n't have", 2, 'have'],
#  ["n't remember", 1, 'remember'],
#  ['nabi happy', 1, 'happy'],
#  ['nets and', 1, 'and'],
#  ['never played', 1, 'played'],
#  ['new i', 1, 'i'],
#  ['night.', 1, 'night.'],
#  ['not compromise', 1, 'compromise'],
#  ['not lose', 1, 'lose'],
#  ['now turn', 1, 'turn'],
#  ['now,', 1, 'now,'],
#  ['of choppy', 1, 'choppy'],
#  ['of controversy', 2, 'controversy'],
#  ['of cricket', 1, 'cricket'],
#  ['of delivery', 1, 'delivery'],
#  ['of fours', 1, 'fours'],
#  ['of him', 1, 'him'],
#  ['of play', 1, 'play'],
#  ['of pleasure', 1, 'pleasure'],
#  ['of positives', 1, 'positives'],
#  ['of runs', 1, 'runs'],
#  ['of series', 1, 'series'],
#  ['of t20', 1, 't20'],
#  ['of the', 6, 'the'],
#  ['off age', 1, 'age'],
#  ['off his', 1, 'his'],
#  ['off test', 1, 'test'],
#  ['off they', 1, 'they'],
#  ['on february', 1, 'february'],
#  ['on improving', 1, 'improving'],
#  ['on my', 1, 'my'],
#  ['on the', 2, 'the'],
#  ['on this', 1, 'this'],
#  ['one of', 1, 'of'],
#  ['one type', 1, 'type'],
#  ['one-', 1, 'one-'],
#  ['only good', 1, 'good'],
#  ['only one', 1, 'one'],
#  ['only thought', 1, 'thought'],
#  ['other to', 1, 'to'],
#  ['out /', 1, '/'],
#  ['out of', 1, 'of'],
#  ['out to', 1, 'to'],
#  ['over to', 1, 'to'],
#  ['over was', 1, 'was'],
#  ['over.', 1, 'over.'],
#  ['over?', 1, 'over?'],
#  ['overall performance', 1, 'performance'],
#  ['overs.', 1, 'overs.'],
#  ['partnership to', 1, 'to'],
#  ['partnership was', 1, 'was'],
#  ['passage of', 1, 'of'],
#  ['passing game', 1, 'game'],
#  ['perfectly.', 1, 'perfectly.'],
#  ['performance.', 1, 'performance.'],
#  ['play 212', 1, '212'],
#  ['play.', 1, 'play.'],
#  ['played 16', 1, '16'],
#  ['played and', 1, 'and'],
#  ['played good', 1, 'good'],
#  ['played the', 1, 'the'],
#  ['played this', 1, 'this'],
#  ['played,', 1, 'played,'],
#  ['player of', 3, 'of'],
#  ['pleasure to', 1, 'to'],
#  ['plenty of', 1, 'of'],
#  ['positives from', 2, 'from'],
#  ['pressure was', 2, 'was'],
#  ['pretty well', 1, 'well'],
#  ['racing,', 1, 'racing,'],
#  ['ravi bishnoi', 1, 'bishnoi'],
#  ['really good', 1, 'good'],
#  ['really happy', 1, 'happy'],
#  ['really well', 1, 'well'],
#  ['record 5th', 1, '5th'],
#  ['red-', 1, 'red-'],
#  ['regular passage', 1, 'passage'],
#  ['remember when', 1, 'when'],
#  ['retired hurt', 2, 'hurt'],
#  ['retired out', 1, 'out'],
#  ['rinku and', 1, 'and'],
#  ['rinku in', 1, 'in'],
#  ['rinku.', 1, 'rinku.'],
#  ['rohit after', 1, 'after'],
#  ['rohit collects', 1, 'collects'],
#  ['rohit declared', 1, 'declared'],
#  ['rohit has', 1, 'has'],
#  ['rohit sharma', 1, 'sharma'],
#  ['rounder you', 1, 'you'],
#  ['rules perfectly', 1, 'perfectly'],
#  ['runs after', 1, 'after'],
#  ['runs and', 1, 'and'],
#  ['runs on', 1, 'on'],
#  ['savour for', 1, 'for'],
#  ['scored a', 1, 'a'],
#  ['season continues', 1, 'continues'],
#  ['second super', 1, 'super'],
#  ['second time', 1, 'time'],
#  ['series -', 1, '-'],
#  ['series against', 1, 'against'],
#  ['series and', 2, 'and'],
#  ['series that', 1, 'that'],
#  ['series,', 1, 'series,'],
#  ['sharma:', 1, 'sharma:'],
#  ['shivam dube', 1, 'dube'],
#  ['shortly in', 1, 'in'],
#  ['show.', 1, 'show.'],
#  ['showed what', 1, 'what'],
#  ['sixes ,', 1, ','],
#  ['skipper:', 2, 'skipper:'],
#  ['smash on', 1, 'on'],
#  ['smiles in', 1, 'in'],
#  ['so,', 1, 'so,'],
#  ['some positives', 1, 'positives'],
#  ['someone like', 1, 'like'],
#  ['something new', 1, 'new'],
#  ['space for', 1, 'for'],
#  ['spin in', 1, 'in'],
#  ['sri lanka', 1, 'lanka'],
#  ['starting on', 1, 'on'],
#  ['starts shortly', 1, 'shortly'],
#  ['strength pretty', 1, 'pretty'],
#  ['sublime hundred', 1, 'hundred'],
#  ['such is', 1, 'is'],
#  ['super over', 2, 'over'],
#  ['super overs', 1, 'overs'],
#  ['super-', 1, 'super-'],
#  ['superover,', 1, 'superover,'],
#  ['superover.', 1, 'superover.'],
#  ['t20 leagues', 1, 'leagues'],
#  ['t20 world', 2, 'world'],
#  ['t20,', 1, 't20,'],
#  ['t20i.', 1, 't20i.'],
#  ['take runs', 1, 'runs'],
#  ['take some', 1, 'some'],
#  ['talking to', 1, 'to'],
#  ['team batting', 1, 'batting'],
#  ['team moving', 1, 'moving'],
#  ['teams.', 1, 'teams.'],
#  ['test against', 1, 'against'],
#  ['test series', 1, 'series'],
#  ['that at', 1, 'at'],
#  ['that he', 2, 'he'],
#  ['that i', 1, 'i'],
#  ['that intent', 1, 'intent'],
#  ['that the', 1, 'the'],
#  ['that to', 1, 'to'],
#  ['the 3rd', 1, '3rd'],
#  ['the 5', 1, '5'],
#  ['the back', 1, 'back'],
#  ['the backend', 1, 'backend'],
#  ['the ball', 1, 'ball'],
#  ['the bat', 1, 'bat'],
#  ['the batter', 1, 'batter'],
#  ['the boys', 1, 'boys'],
#  ['the captain', 1, 'captain'],
#  ['the champions', 1, 'champions'],
#  ['the chinnaswamy', 1, 'chinnaswamy'],
#  ['the coverage', 1, 'coverage'],
#  ['the cricket', 1, 'cricket'],
#  ['the crowd', 1, 'crowd'],
#  ['the domestic', 1, 'domestic'],
#  ['the first', 2, 'first'],
#  ['the former', 1, 'former'],
#  ['the game', 1, 'game'],
#  ['the heartbeat', 1, 'heartbeat'],
#  ['the indian', 2, 'indian'],
#  ['the intent', 1, 'intent'],
#  ['the ipl', 2, 'ipl'],
#  ['the job', 1, 'job'],
#  ['the last', 2, 'last'],
#  ['the length', 1, 'length'],
#  ['the match', 2, 'match'],
#  ['the nets', 1, 'nets'],
#  ['the night', 1, 'night'],
#  ['the one', 1, 'one'],
#  ['the overall', 1, 'overall'],
#  ['the partnership', 1, 'partnership'],
#  ['the player', 1, 'player'],
#  ['the pressure', 2, 'pressure'],
#  ['the regular', 1, 'regular'],
#  ['the rules', 1, 'rules'],
#  ['the second', 1, 'second'],
#  ['the series', 2, 'series'],
#  ['the super', 1, 'super'],
#  ['the superover', 2, 'superover'],
#  ['the t20', 1, 't20'],
#  ['the team', 1, 'team'],
#  ['the trophy', 2, 'trophy'],
#  ['the upcoming', 1, 'upcoming'],
#  ['the way', 1, 'way'],
#  ['the world', 1, 'world'],
#  ['their attention', 1, 'attention'],
#  ['their best', 1, 'best'],
#  ['them if', 1, 'if'],
#  ['there and', 1, 'and'],
#  ['there any', 1, 'any'],
#  ['there are', 1, 'are'],
#  ['there with', 1, 'with'],
#  ['there,', 1, 'there,'],
#  ['these 3', 1, '3'],
#  ['they go', 1, 'go'],
#  ['things i', 1, 'i'],
#  ['think i', 1, 'i'],
#  ['this experience', 1, 'experience'],
#  ['this ground', 1, 'ground'],
#  ['this happened', 1, 'happened'],
#  ['this is', 1, 'is'],
#  ['this kind', 1, 'kind'],
#  ['this series', 2, 'series'],
#  ['this space', 1, 'space'],
#  ['thought is', 1, 'is'],
#  ['thought we', 1, 'we'],
#  ['time this', 1, 'this'],
#  ['time,', 1, 'time,'],
#  ['times in', 1, 'in'],
#  ['to bat', 2, 'bat'],
#  ['to be', 2, 'be'],
#  ['to both', 1, 'both'],
#  ['to defend', 1, 'defend'],
#  ['to drag', 1, 'drag'],
#  ['to each', 1, 'each'],
#  ['to ensure', 1, 'ensure'],
#  ['to get', 1, 'get'],
#  ['to haul', 1, 'haul'],
#  ['to improve', 1, 'improve'],
#  ['to not', 1, 'not'],
#  ['to only', 1, 'only'],
#  ['to rinku', 1, 'rinku'],
#  ['to savour', 1, 'savour'],
#  ['to show', 1, 'show'],
#  ['to smash', 1, 'smash'],
#  ['to take', 1, 'take'],
#  ['to the', 2, 'the'],
#  ['told by', 1, 'by'],
#  ['tough to', 1, 'to'],
#  ['towards red', 1, 'red'],
#  ['trophy and', 1, 'and'],
#  ['trophy behind', 1, 'behind'],
#  ['trying to', 1, 'to'],
#  ['turn attention', 1, 'attention'],
#  ['turn their', 1, 'their'],
#  ['two games', 1, 'games'],
#  ['type of', 1, 'of'],
#  ['unfortunately we', 1, 'we'],
#  ['up the', 1, 'the'],
#  ['upcoming t20', 1, 't20'],
#  ['us in', 1, 'in'],
#  ['us to', 1, 'to'],
#  ['used to', 1, 'to'],
#  ['very calm', 1, 'calm'],
#  ['walked away', 1, 'away'],
#  ['want to', 3, 'to'],
#  ['wanted someone', 1, 'someone'],
#  ['was a', 1, 'a'],
#  ['was confident', 1, 'confident'],
#  ['was followed', 1, 'followed'],
#  ['was important', 2, 'important'],
#  ['was played', 1, 'played'],
#  ['was racing', 1, 'racing'],
#  ['was rohit', 1, 'rohit'],
#  ['was the', 2, 'the'],
#  ['was there', 2, 'there'],
#  ['was told', 1, 'told'],
#  ['watching this', 1, 'this'],
#  ['waters at', 1, 'at'],
#  ['way the', 1, 'the'],
#  ['we (', 1, '('],
#  ['we are', 1, 'are'],
#  ['we did', 1, 'did'],
#  ['we finally', 1, 'finally'],
#  ['we got', 1, 'got'],
#  ['we know', 1, 'know'],
#  ['we lost', 1, 'lost'],
#  ['we never', 1, 'never'],
#  ['we played', 1, 'played'],
#  ['we scored', 1, 'scored'],
#  ['we thought', 1, 'thought'],
#  ['we want', 1, 'want'],
#  ['we will', 1, 'will'],
#  ['we would', 1, 'would'],
#  ['we wrap', 1, 'wrap'],
#  ["we'll", 1, "we'll"],
#  ['well done', 1, 'done'],
#  ['well for', 2, 'for'],
#  ['well.', 3, 'well.'],
#  ['what he', 2, 'he'],
#  ['what is', 1, 'is'],
#  ['when was', 1, 'was'],
#  ['wicket partnership', 1, 'partnership'],
#  ['wickets and', 1, 'and'],
#  ['wickets from', 1, 'from'],
#  ['will help', 1, 'help'],
#  ['will take', 1, 'take'],
#  ['will turn', 1, 'turn'],
#  ['win before', 1, 'before'],
#  ['win to', 1, 'to'],
#  ['winner for', 1, 'for'],
#  ['winner.', 1, 'winner.'],
#  ['with each', 1, 'each'],
#  ['with nabi', 1, 'nabi'],
#  ['with only', 1, 'only'],
#  ['with plenty', 1, 'plenty'],
#  ['with the', 3, 'the'],
#  ['worked on', 1, 'on'],
#  ['world cup', 2, 'cup'],
#  ['world.', 1, 'world.'],
#  ['would be', 1, 'be'],
#  ['would win', 1, 'win'],
#  ["wouldn't", 1, "wouldn't"],
#  ['wrap up', 1, 'up'],
#  ['you always', 1, 'always'],
#  ['zadran afghanistan', 1, 'afghanistan']]

# %%
df=pd.DataFrame(prob_dist,columns=['pair','freq','output'])

# %%
df.head()
# Out:
#        pair  freq   output
# 0   ibrahim     1  ibrahim
# 1      ravi     1     ravi
# 2     rohit     2    rohit
# 3    shivam     1   shivam
# 4  'll bowl     1     bowl

# %%
df.shape
# Out:
# (733, 3)

# %%
df[df['freq']>1].shape
# Out:
# (73, 3)

# %%
def predict(word):
    df_pred=[]
    for i in df.values:
        if i[0].split(' ')[0]==word:
            df_pred.append([i[0],i[1],i[2]])
            #print(i[0],i[1],i[2])
    df_pred=pd.DataFrame(df_pred,columns=['pair','freq','output'])
    words=df_pred.sort_values(by='freq',ascending=False).head()['output'].values
    #print(words)
    return words

# %%
df_pred.sort_values(by='freq',ascending=False)
# Out:
#              pair  freq    output
# 0     rohit after     1     after
# 1  rohit collects     1  collects
# 2  rohit declared     1  declared
# 3       rohit has     1       has
# 4    rohit sharma     1    sharma

# %%
df_pred.sort_values(by='freq',ascending=False).head()['output'].values
# Out:
# array(['after', 'collects', 'declared', 'has', 'sharma'], dtype=object)

# %%
predict(word='rohit')
# Out:
# array(['after', 'collects', 'declared', 'has', 'sharma'], dtype=object)

# %%
word='rohit'
out=word + ' '
for i in range(5):
    print(word)
    pred=predict(word)
    #print(pred[0])
    print('Predicted Choices : ',pred)
    
    #print(pred[0],end=' ')
    word=input('Enter the next word from above choices')
    out+=word + ' '
print(out)
# Out:
# rohit
# Choices :  ['after' 'collects' 'declared' 'has' 'sharma']
# Enter the next word from above choicescollects
# collects
# Choices :  ['the']
# Enter the next word from above choicesthe
# the
# Choices :  ['last' 'first' 'ipl' 'trophy' 'indian']
# Enter the next word from above choicestrophy
# trophy
# Choices :  ['and' 'behind']
# Enter the next word from above choicesand
# and
# Choices :  ['we' 'it' 'this' 'he' 'i']
# Enter the next word from above choiceswe
# rohit collects the trophy and we
